# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = []
with open('csvfile.csv', 'rb') as csvfile:
    lines = csv.reader(csvfile)
    for row in lines:
            data.append(np.asarray(row,dtype=float))

# %%
y3 = np.fft.fft(data[3])

# %%
np.shape(y3)
# Out:
# (343,)

# %%
plt.plot(abs(y3[:len(y3)/2]))

# %%
import scipy.fftpack

# Number of samplepoints
N = 600
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(120.0 * 2.0*np.pi*x)
yf = scipy.fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)

fig, ax = plt.subplots()
ax.plot(xf, 2.0/N * np.abs(yf[:N/2]))
plt.show()

# %%
len(y3)
# Out:
# 343

# %%
plt.plot(abs(y3))
